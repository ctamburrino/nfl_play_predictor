# %% [markdown]
# ## Data Type Encoding & Mapping
#
# Transforming data type to either numeric or boolean
#
# ##### Check pruned dataset data types

# %%
# Imports
import pandas as pd

# %%
# Load filtered dataset
print('Loading CSV (this may take a while for large files)...')
df = pd.read_csv("../dataset/nfl_filtered.csv", low_memory=False, index_col=0)
print("Shape of original dataset: ", df.shape)
# Out:
# Loading CSV (this may take a while for large files)...
# Shape of original dataset:  (319369, 19)
